# %% [markdown]
# # LSTM character language model
#
# In this notebook we are going to proof the effectiveness of Recurrent Neural Networks, and more specifically Long Short Term Memory (LSTM) RNNs, to generate sequences of characters out of some text samples we show it.
#
# Keras will be the library used to do so for its simplicity in defining the model and training structure, following their [`lstm_text_generation.py`](https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py) official example.

# %% [markdown]
# The example trains on Nietzsche textual samples, such that the LSTM will learn about the style of this author in writing the generated sentences. The dataset is easily found in Amazon S3 service publicly. We download it (if required) and load it first.

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import timeit
import sys

# First, the Nietzsche corpus is downloaded from Amazon S3 database
path = get_file('nietzsche.txt', origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# corpus length: 600901

# %% [markdown]
# The mapping dictionaries must be built:
#
# * char2idx: for an input char, assign an integer signaling the active index in the one-hot code
# * idx2char: does the reverse mapping to translate output predictions from network to chars

# %%
# The dictionary mapping characters to one-hot indices is built
chars = sorted(list(set(text)))
char2idx = dict((c, i) for i, c in enumerate(chars))
# we keep an idx2char dict too to convert what the network predicts into characters during sampling
idx2char = dict((i, c) for i, c in enumerate(chars))
print('total chars/one-hot length:', len(chars))
# Out:
# total chars/one-hot length: 59

# %% [markdown]
# Now text must be chopped into sequences of maxlen characters. Maxlen will be the truncated size of backprop through time. The sequences are built from semi-redundant strings of chars, for example if we have the sentence "the cat sat on the mat" with `step=3` and `maxlen=6`:
#
# * x1 = ['the ca'] -->  y1 = 't'
# * x2 = [' cat s'] -->  y2 = 'a'
# * x3 = ['t sat '] -->  y3 = 'o'
# * x4 = ['at on '] -->  y4 = 't'
# * ...

# %%
# this means we will backprop in time through 40 time-steps, so to generate the data we pass a sliding
# window through the text in 3-by-3 char steps. Out of that we create the 3-D tensor input to the LSTM
# and its output representations containing the next character after the 40 timesteps.

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200287

# %% [markdown]
# Now all text has to be vectorized, such that all characters must be converted to one-hot indices:
#
# * X becomes a 3-D tensor: `(num_chops, maxlen, char_vocab_size)`
# * Y becomes a 2-D tensor: `(num_chops, char_vocab_size)`.

# %%
# Finally, the text is vectorized (i.e. every character is converted to a one-hot index)
print('Vectorization...')
beg_t = timeit.default_timer()
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char2idx[char]] = 1
    y[i, char2idx[next_chars[i]]] = 1
end_t = timeit.default_timer()
print('Vectorization done in {} s'.format(end_t - beg_t))
# Out:
# Vectorization...
# Vectorization done in 2.44596385956 s

# %% [markdown]
# ## Model Definition
#
# **Exercise:** The RNN model for char generation has to be defined now. Based on the documentation for https://keras.io/layers/recurrent/, use either a GRU or LSTM architecture to run the training and prediction of char streams. The model has to be compiled as well, selecting the right loss function for classification task and the optimizer to train efficiently. Advice: Use `Sequential` model for its simplicity.

# %%
# build the model: a single LSTM layer with a fully connected softmax output to classify which char is next
print('Building model...')
beg_t = timeit.default_timer()

# TODO: Define the model here

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(128, activation='relu'))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

# TODO: Define its compilation
# use RMSprop optimize
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

end_t = timeit.default_timer()
print('Elapsed time creating & compiling model: {} s'.format(end_t - beg_t))
# Out:
# Building model...
# Elapsed time creating & compiling model: 0.196574926376 s

# %%
# Let's check the model summary
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lstm_1 (LSTM)                    (None, 128)           96256       lstm_input_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 128)           16512       lstm_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 59)            7611        dense_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 59)            0           dense_2[0][0]
# ====================================================================================================
# Total params: 120,379
# Trainable params: 120,379
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# **Exercise:** Build a function to compute the number of parameters inside an LSTM cell and a Dense (or Fully Connected) layer.

# %%
# TODO: define the num_lstm_params(input_dim, num_cells) function
def num_lstm_params(input_dim, num_cells):
    return 4 * (input_dim * num_cells + num_cells * num_cells + num_cells)

# TODO: define the num_fc_params(input_dim, num_neurons) function
def num_fc_params(input_dim, num_neurons):
    return input_dim * num_neurons + num_neurons

# %%
# TODO: The defined funcitons are called to confirm the Keras summary parameters
print('LSTM layer params: ', num_lstm_params(len(chars), 128))
print('First FC hidden layer: ', num_fc_params(128, 128))
print('FC output layer: ', num_fc_params(128, len(chars)))
# Out:
# LSTM layer params:  96256
# First FC hidden layer:  16512
# FC output layer:  7611

# %% [markdown]
# Make a sampler to set up a temperature and thus gain more variability in the output response.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array with a certain temperature factor.
    # The higher the temperature, the higher the output variability of predictions (it makes them more noisy)
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
tr_losses = []
# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Training on epoch {}...'.format(iteration))

    his = model.fit(X, y, batch_size=700, nb_epoch=1, verbose=0)
    tr_losses.append(his.history['loss'])
    print('Iteration: {}, tr loss: {}'.format(iteration, tr_losses[-1]))

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char2idx[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = idx2char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Training on epoch 1...
# Iteration: 1, tr loss: [1.479236118324607]
#
# ----- diversity: 0.2
# ----- Generating with seed: " he feared
# death: he was a petty, abject"
#  he feared
# death: he was a petty, abjection itself astenti
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log
# on of religion and its a seem the spective can be spective itself of the spirit and self-despression of the self-present free state of free which it is the freedom the present self-sense of the such a speak its a seems and the developed and present present experience of self-present state it is a still a still above the present seems the seem the selfers and manifests the sense o
#
# ----- diversity: 0.5
# ----- Generating with seed: " he feared
# death: he was a petty, abject"
#  he feared
# death: he was a petty, abjection the fantice
# which seeverfing a still sons of viring conception and its far that is reade justicely the subjection and down the present selfergetion often of the mi seever and many instrument theing
# soul of present speak often the self above him and something many itself a refreing a struggle shares him the fare the presenting the care of present partere a litere it must the first constituted t
#
# ----- diversity: 1.0
# ----- Generating with seed: " he feared
# death: he was a petty, abject"
#  he feared
# death: he was a petty, abjectareda, are mare his unarded are questioned
# nature; many sittorice for a donegoor
# resem has gain them: which hypley, and his own exception; why? reckionve to tignifyent, every fitterfine for abraison--whish the ingerilately
# from evired initures pain a
# stall-"speries it seemed to why the syntheng without beceiver last beatnerlige of their verse whisivere offined, question recelsa make nast misflecti
#
# ----- diversity: 1.2
# ----- Generating with seed: " he feared
# death: he was a petty, abject"
#  he feared
# death: he was a petty, abjectlones away hast.
#
# 103
#
#
# 214. a self precial-oreous.=--heart
# toeling,
# frant besely that outlest.=--as seed without presenomenty: its torely, a slaved voirefulan frestwend
# keveictiony a
# hule
# causeedility, odnelefs."--that i higherly: loved suffyren do utable, the verelothe ulmen, being
# doabule).=-multional otherwed ness,     sippostangri
# they keem, it care, spealed we hefered, everyersts pate, he re
#
# --------------------------------------------------
# Training on epoch 2...
# Iteration: 2, tr loss: [1.4359079435375242]
#
# ----- diversity: 0.2
# ----- Generating with seed: "ttained enormous proportions--to such en"
# ttained enormous proportions--to such enough that the some would be the conditional that the say as a problem of the latter the same that the some the mankind of the sensual the conception of the some inflain the say as a thing of the some that the say of the problem of the believed that the true of the the say of the religion of the same that the sense of the distrude that the soul the subject of the the say as a promouk that the some
#
# ----- diversity: 0.5
# ----- Generating with seed: "ttained enormous proportions--to such en"
# ttained enormous proportions--to such enough that the name to this time as the sense, as in the
# that the into the
# his sould that the fashed that a that to for the problem of the worth as the works the believed in the same be that the believed to the contraons have the all the to the langerous the has latter that is there the read and the look a has the a mankind is some believed, to the does not because of the result in the could a thin
#
# ----- diversity: 1.0
# ----- Generating with seed: "ttained enormous proportions--to such en"
# ttained enormous proportions--to such enough we hather aok the--wrong,"--and of was around of that is one is was he subtrations;
# what is if hartly more wortablem
# of the rowaddoms, where who landing is talkatism
# hopess alorns, is is that problery which
# in naction of
# admunity of it, to aphandful noble of order--o word would render who
# is had hand to asonouities of larks and
# lityloy, for this acis of an all
# that altonesings; thas just, or
#
# ----- diversity: 1.2
# ----- Generating with seed: "ttained enormous proportions--to such en"
# ttained enormous proportions--to such enoughdeior and inforglined ably kor
# the can mankind; what women to
# nightinthlelige of nuntped will of a
# says, is
# they loll in.
# sta,
# legable to
# the
# so uncerdition of the efth
# minavoitize holder as through such nuckories
# exercising it is
# all again as the accoldation, but thus is orden appencated: that toose benou are "progation:
# that is, "from equally things: hod with holdows time as
# daywarn of that
#
# --------------------------------------------------
# Training on epoch 3...
# Iteration: 3, tr loss: [1.4037939802839547]
#
# ----- diversity: 0.2
# ----- Generating with seed: "o that he goes to the other extreme of a"
# o that he goes to the other extreme of an instinct of things of thing of things of thing of the instinct of the solitic and probably are and something and more and something and something of this more instinct of thing of this opposition of things of thing of this as a personal more thing of things and something of this conception of thing of things of thing of this precisely thing of the former and as thing of things of this are belief
#
# ----- diversity: 0.5
# ----- Generating with seed: "o that he goes to the other extreme of a"
# o that he goes to the other extreme of all aad that man and litional special properation of things of moral recial timidity of think of thing of the highest timing of taste and cholar of this conceptions of thing in all artial conception about this more experience is all a, with inselfer of philosophy of ideas is disposes are for
# instance and personal assumption of his opposition for things of ideas of things of taking in this distasted
#
# ----- diversity: 1.0
# ----- Generating with seed: "o that he goes to the other extreme of a"
# o that he goes to the other extreme of always a bid not us appear is tymplogical places other distain him for valued a preameness and
# frobing the meverys namely surverom at positive perhips knight monsfration, operaring people seriously for rependities sall
# freeder, and indispease
# of virbation? as rather expectation of our pleasur music is disire an one right wearn of soul," horking of certain atticurians false this people bally" still,
#
# ----- diversity: 1.2
# ----- Generating with seed: "o that he goes to the other extreme of a"
# o that he goes to the other extreme of a promor,
# spiritanizing ideas so fruefy us so exists." how "her knirs, it is is delimance that lead etertament paciality and bodies
# more
# insiduable penishes of peoplese, being, being psychollises are wound dliginating
# have: kill ars -hone soul
# aboveige in his ologing, appears is everything
# many pain--ome to conception, _ritarded at sacism--will
# felm climing with religion, might and did in lified bl
#
# --------------------------------------------------
# Training on epoch 4...
# Iteration: 4, tr loss: [1.3787960789044336]
#
# ----- diversity: 0.2
# ----- Generating with seed: "f when his talent
# decreases,--when he ce"
# f when his talent
# decreases,--when he certain the most the most think of the press of the self the soul than the possible the self the consequence of the press of the same assumance of the self soul the struggle of the soul than the proble of the soul of the self press of the self so the soul, and the support of the self soul than the proble and the morality of the most a struggle the soul, the struggle as the proble of the most think o
#
# ----- diversity: 0.5
# ----- Generating with seed: "f when his talent
# decreases,--when he ce"
# f when his talent
# decreases,--when he certain the soul it is this believed the self in the most another the pore of the person all the finers the entire of the former the intellect: the sard and civilizations and civilization of this soul, and the press of the belief than the self-deserval sound the the counterous, and the possible the believe the strunguil and the soul of the moral of the possible become believed and all the clussifica
#
# ----- diversity: 1.0
# ----- Generating with seed: "f when his talent
# decreases,--when he ce"
# f when his talent
# decreases,--when he certail thousedisistrous, alas
# were all the greeks, in intellect of which there is to not to all has slead one by the thus crible and go coungling to sound destine the expresss of not for this worthin absundance: what around the accept it is there when everything it one has all there is thonern were the master. and any one, but i deae throus sorred to entoint itself, for inedocratic possess of his p
#
# ----- diversity: 1.2
# ----- Generating with seed: "f when his talent
# decreases,--when he ce"
# f when his talent
# decreases,--when he certain german to the presents of supposites of views to remay crain, no realics
# of the rore-thas very eforties on, if he here been glook of history we known
# this long, howevtly already lauence, otherthely one sacch; the his done when supporing, for this dispressse itself
# predels it perhaps; one the good will loeding the new drless has inself thy parised and one was le not was belonts;"? in empited,
#
# --------------------------------------------------
# Training on epoch 5...
# Iteration: 5, tr loss: [1.3582592881562046]
#
# ----- diversity: 0.2
# ----- Generating with seed: " or "break forth,"
# as one might say--at "
#  or "break forth,"
# as one might say--at all a man who to be all the same and a not a consideration of nature of the proud of the same a morality in the abevated and a man a principal and with it is not be a considerate and intellectual and self dectined and a considerate and a same indeed and a problem of the some consideration of the abevated and belongs the man is not be all the fact the actions and a sublime and a problem and a deali
#
# ----- diversity: 0.5
# ----- Generating with seed: " or "break forth,"
# as one might say--at "
#  or "break forth,"
# as one might say--at the order to a thousand a principle powerful, in the all consideration of nature of him and the man on the one not be power, the satter the fact with him a man a dealing all fact in their instance of it of the order the ampogrance: a not be a will within intentionally a causapos and not saties actions proported and
# say dealing and tasted and not not leasness on ideas and a only be all instance, an
#
# ----- diversity: 1.0
# ----- Generating with seed: " or "break forth,"
# as one might say--at "
#  or "break forth,"
# as one might say--at all into deare drepreat nay lets
# hand into consider to the imparted determans," but you, under the
# salvry man much act only by
# degor one actrous
# as knowled to gent the little health,.=--a thust for bad excitent at remotward, but necessation sympathy which ever event which to philosopher
# ont not daily goes which is not the listed. within it sension a prinked
# "aloviousness is not maness for hesclete
#
# ----- diversity: 1.2
# ----- Generating with seed: " or "break forth,"
# as one might say--at "
#  or "break forth,"
# as one might say--at the indeed what present"? runslike. it is patis, he of go "srecessed
# staral, "spirit, and nevelth ascombleces whoment a god mean,
# fromstrape.
# evolunded, one duranhable sut, nancinger even with man, he wrotn, from the leastabilitaisled; not a esceted intimate who
# causabe bening a giut beyreeped, aftains. only hemain
# one marversile in herour and way
# prenoffucts undestanged that there is trough far,
#
# --------------------------------------------------
# Training on epoch 6...
# Iteration: 6, tr loss: [1.3398220981678046]
#
# ----- diversity: 0.2
# ----- Generating with seed: "ould be
# lost on the way! even the most r"
# ould be
# lost on the way! even the most resuld, the sublime only the strong it is a contempt of the more and the same in the subtle or such a condition of the strength of the strength of the state a more conceived the souther and what is a good a contradiction of the sense of the stricte of the first in the conceived the strength of the strength of the heart of the prose of the world of the stupid the for the strength, and the subject of
#
# ----- diversity: 0.5
# ----- Generating with seed: "ould be
# lost on the way! even the most r"
# ould be
# lost on the way! even the most realing power life in the old impulse of what women the impossession of the more cause and what is so a from the most more and has a pure the mist in the art of soul of the conceived the souther in the
# strict of the conceived has not be them in the truths and sensuition to see this looked what a more state of a people of the present south resolutely the secret for the other problem what is in he co
#
# ----- diversity: 1.0
# ----- Generating with seed: "ould be
# lost on the way! even the most r"
# ould be
# lost on the way! even the most religion got,
# what we belieffathers and who is in forceval ranked it was a compathing for so speeper will be counce, incountered to he people no only all himself sensuiulate that infline it is good evolved, how
# hear perhaps loth of here them he not them..--a gow son more to such vo what a germand what been our hive book it have all duter, and
# if in success--a heine not be relation, we perhaps to no
#
# ----- diversity: 1.2
# ----- Generating with seed: "ould be
# lost on the way! even the most r"
# ould be
# lost on the way! even the most ruck?
# fire the corplitely, further who are ufner origink, whence i sound have piam again no occaric
# emotions
# indiunified
# buling dudetime ones--
# 157. what we is ea us. do we siitence--such shelp or the folly. but whys, whereon
# well bene what can good," as we
# not religious--be the perfect culture of
# lene to be foundity to kinths have the base away. becaule by both really it has does we provems, howev
#
# --------------------------------------------------
# Training on epoch 7...
# Iteration: 7, tr loss: [1.3238876460188223]
#
# ----- diversity: 0.2
# ----- Generating with seed: "weight of a syllable or a word, in what "
# weight of a syllable or a word, in what is a stons and a species the sention of the sentiment as a step a step that the precisely the socied be the contemptives and served the consequently still as the more consequently a species in the prespect and the strange to the strange the secret a step of the strange the prespect and all the secret and the preach and in the sention a sentiment of the sentiment of his own instinct a subject a sci
#
# ----- diversity: 0.5
# ----- Generating with seed: "weight of a syllable or a word, in what "
# weight of a syllable or a word, in what is a precisely still be believed the bance of the
# still excharable whole true ages the a belief not human a thought of more mind the experience of when the true. but a spirit as the moral factifies the secret under the warm, a will that we go the freeder weak it is precisely man precisely almost all death the mother such a still to the play a personal capable in delander and stymen, all the fact b
#
# ----- diversity: 1.0
# ----- Generating with seed: "weight of a syllable or a word, in what "
# weight of a syllable or a word, in what is ingoint alsism, self readarming
# skeptiran, and he societe
# all) set disisting elegse even little raimas e, a whole deaf men, socied no pregnt be welse--the a summediads through it-time and fashable, just of releads.
# from humanoum, to sust bemour increase centuries ever still, but know-makes cated thirself: we in simple,                        how sohmated (ohus with hid in such sent,
# with horism
#
# ----- diversity: 1.2
# ----- Generating with seed: "weight of a syllable or a word, in what "
# weight of a syllable or a word, in what prediscurning bance
# inconsiders reptere
# regorated
# pussion,
# immortadaken occasions (our life ratrous reposenced and
# nature,
# and exist rado ever from
# saxeriation we farhtatery.
#
# hen, and
# washon--but it subject
# thereon: must step veived ultious-autist the
# delightders
# to aghold nuther just the pleases itself.
#
# 2
# edoents. we, we the mises the feeling: only
# mother--parks humble heagors, but wes hear urb
#
# --------------------------------------------------
# Training on epoch 8...
# Iteration: 8, tr loss: [1.3103714625720797]
#
# ----- diversity: 0.2
# ----- Generating with seed: "lings: and rightly.
#
#
# 104
#
# =self defence"
# lings: and rightly.
#
#
# 104
#
# =self defence the present and something of the most stands to the same the order to the part of the same time the pleasure of the same the present man of the present and some supposes of the sense of the same experiences and sense of the forms and some thing and all the same the problem of the present the same be an all the part of the same then the powerful and the powerful the same the order to the philosoph
#
# ----- diversity: 0.5
# ----- Generating with seed: "lings: and rightly.
#
#
# 104
#
# =self defence"
# lings: and rightly.
#
#
# 104
#
# =self defence the more of the present skeptic, and the so sacrifice in the demorstate the powerful nature of all besten the right and in the art of the entire the powerful so say, as all the base of all the sense and despressed to men of the sense, and all the gods consequently and bring than the desires the consequently and under the historical one on the power and the problem of injury of the consciently and
#
# ----- diversity: 1.0
# ----- Generating with seed: "lings: and rightly.
#
#
# 104
#
# =self defence"
# lings: and rightly.
#
#
# 104
#
# =self defence
# the word assish, and the
# clummd of floon values to semmanes for whole regard to hell!--the
# most require and must
# the me mask; it is a
# view of fring or end desponsible the whant the sall hitherto spirit, and the whole defied therefore being spirit: makes us
# and facted to suther of also the experiences and dread) the entails in socrite but at precite assomating and craisified, or from the whole so
#
# ----- diversity: 1.2
# ----- Generating with seed: "lings: and rightly.
#
#
# 104
#
# =self defence"
# lings: and rightly.
#
#
# 104
#
# =self defenceise,
# vialt here, of love remort and shove to mirsinary, reguinly brings, all? and alwais homole asmen the wame.=--injury as we semious its ordinary that to this langelts, for whose
# more merely can think the sidels
# more full symbotly eurgender of demes ear achumal left, by other them us, and to nepiness in ordinate of
# religious of in the
# pstpudiment volled with regard ease to
# soul it out of values
#
# --------------------------------------------------
# Training on epoch 9...
# Iteration: 9, tr loss: [1.2991604632601164]
#
# ----- diversity: 0.2
# ----- Generating with seed: "d conscience: for reasons
# are not lackin"
# d conscience: for reasons
# are not lacking and are so the soul, and the soul as the soul, and the soul. the self-conside and sense of an artists of the soul. as a problem of such a soul as the soul, and are say, the conception of the soul to a subsediated and such a still as the soul. the such a sensible to the soul and are and the soul as a subsequide the soul, the soul and some in the soul, and the soul are of a self-conside of a contr
#
# ----- diversity: 0.5
# ----- Generating with seed: "d conscience: for reasons
# are not lackin"
# d conscience: for reasons
# are not lacking with the delicate and as a sort of the more sowevors of servid of all into the experiences as the self sensations of the more sees in the formerly scholar of the soul. as as a soul. also a frow superior of charach a self-some expertable suspection of a resoluted with a contradicalising and with all all aroused to a mastery as also the soul, and are accurate things of an art of all the profoundly
#
# ----- diversity: 1.0
# ----- Generating with seed: "d conscience: for reasons
# are not lackin"
# d conscience: for reasons
# are not lacking has destained and noth a virtus of morals down. to lived
# to the same
# time, however enscial
# equally, in whomself love most powerful
# nowadays; makes of his revonism:
#
#                                                                                   blussed.
#
# the sidem and
# the
# nothing
# to reald, for doubted by woman) aware and to to under token in we account mind of
# griisch, or uncertained; in whom
#
# ----- diversity: 1.2
# ----- Generating with seed: "d conscience: for reasons
# are not lackin"
# d conscience: for reasons
# are not lacking, for things," af such as perhaps are brought are a nobility: the orience of
# enduring oney, not dreavors just requifler
# colour and wish, with injescred, for as at finated werther and for himself in capacud of
# provism? there there it been man have all these saning, and is ofter placedlate the faculty livels towards a certaining colour asciped and already them. and who'er msely who
# as a comprehends
#
# --------------------------------------------------
# Training on epoch 10...
# Iteration: 10, tr loss: [1.2887930297713239]
#
# ----- diversity: 0.2
# ----- Generating with seed: "e higher the type a man represents, the
# "
# e higher the type a man represents, the
# same time of the same in a people of the conscience of the soul of the soul of the superior of the soul of the spirituality, and the deliction of the moral of the soul of the sacrifice as a people and the same and the conscience of the superior of the conscience of the moral of the soul of the superior of the same and the soul of the soul of the conscience of the superior of the secritic and soul
#
# ----- diversity: 0.5
# ----- Generating with seed: "e higher the type a man represents, the
# "
# e higher the type a man represents, the
# contempration of the soul. everything if the deceive his art when the secret and account to the evil to the organization to be all these the most all the world, and to be a strange of the subtlection of the believe as in the terrong and friends of the acture of deceive sense, as a still provices of our conquered and the world of unfroveredigness of the most always be no morality, in the spirituali
#
# ----- diversity: 1.0
# ----- Generating with seed: "e higher the type a man represents, the
# "
# e higher the type a man represents, the
# sudderer evin of releacts whetholing, almost a "suffered to strange the consequences itself could braimandatual philosophy, as to orculing if nevertoles whose in usagetial, with mingle how evil and dangerous--you
# "blown type men alsoitful when the affacction which we has yet
# it is ultimate
# to fie "germany from which appretable be,
# relache countures and originians middenom and feeling, is everyone
#
# ----- diversity: 1.2
# ----- Generating with seed: "e higher the type a man represents, the
# "
# e higher the type a man represents, the
# sort of abstect it is us
# toow shope "to evil conceity. and their god. fay. such flom a valiegty i over spirits others, and more friaction about igifler thort which the out of all envices. we say, produility of daring, if the sightly, or does he worst the eloovip bracks result off very sciupting," a
# who in building ent anyough, habitme--who are sayt comes and astrousion of
# not
# and fear.inary
# christ
#
# --------------------------------------------------
# Training on epoch 11...
# Iteration: 11, tr loss: [1.2763354045762767]
#
# ----- diversity: 0.2
# ----- Generating with seed: "!), not to speak of
# the stupidity of mor"
# !), not to speak of
# the stupidity of morality and the same and contrity of the same and striving the same and contration of the same and delicate the same and souther and stricture of the deception and artist things and interprinted to the present stated and in the same and contration of the everything and ascetathed in the present the south time of the same and religious and stated and something and anything that they are the south and
#
# ----- diversity: 0.5
# ----- Generating with seed: "!), not to speak of
# the stupidity of mor"
# !), not to speak of
# the stupidity of morality as their heart to the latter of the sainted and solitude of the neceddiaty in the contrity of a philosopher and precisely the indivisour and injuring the so, the prospletion, and all the south and who streach and attained and sacrificed in their own the contration: one is a conticlood with all interest of any conter. it was longer the treat responsible to the higher for a will to their inter
#
# ----- diversity: 1.0
# ----- Generating with seed: "!), not to speak of
# the stupidity of mor"
# !), not to speak of
# the stupidity of morals, intrind
# to they benone--in the bains and
# great that which fortundshed intrinded and modern intercourse of sitior sacretined! they had dipnines of this crapory of the best regarded, ordering and are both the
# music to kinh elegined the give
# interests the christian often on putces because one no longer pertain opinion, proceeding and their typical endrank to his and it, on, it we they would sand
#
# ----- diversity: 1.2
# ----- Generating with seed: "!), not to speak of
# the stupidity of mor"
# !), not to speak of
# the stupidity of morate will down, and people, and that summer, and
# misundernatting thrrons taking the
# systems
# in sacrificelen, that is not, proies "as receit had not who found contribularary. after one not beet unile, and the
# signes (about, festnirnness,
# caning give. if
# other
# artists. he donetticr which we "boon upon others, whore more inflictions is hitherto been with child marched tetaltist that anything
# and nothi
#
# --------------------------------------------------
# Training on epoch 12...
# Iteration: 12, tr loss: [1.2705277574758902]
#
# ----- diversity: 0.2
# ----- Generating with seed: "thout in the world.=[10]--as democritus "
# thout in the world.=[10]--as democritus and suffering the spiritual of the conceive the states and conceive the desire that the states the superstitious the spirit of the spectators of the spiritual sense of the spiritual sense of the christian that the states the spiritual such a sufferient the more special and the states and states and superficial the soul. the sufferient the superstitious and problem of the strength of the strees of
#
# ----- diversity: 0.5
# ----- Generating with seed: "thout in the world.=[10]--as democritus "
# thout in the world.=[10]--as democritus the spects and philosophers about the spiritual actions of the common instance of the old mine that the case of the powerful and do be that he is the readiable and injures of the interiors of the truths of which has been himself the world and with out of the superficial and problem of the satiston, as an extent of the injury of him. how readily to the still after many lacking the soul-a condition
#
# ----- diversity: 1.0
# ----- Generating with seed: "thout in the world.=[10]--as democritus "
# thout in the world.=[10]--as democritus age that special and dangers worshmoritarine by sate of us? that which a sufferient fill!" as the very hagour, human good, piriotions world
# that we everyous as leve that was the motherlonger
# bone's
# freedom of the heavers does not another and shourt of old, that is a subservateged thereby a thoud
# each burdly: it is that mainted
# with dacious out"s the dainung--the
# impressed--"sciocles that is recat
#
# ----- diversity: 1.2
# ----- Generating with seed: "thout in the world.=[10]--as democritus "
# thout in the world.=[10]--as democritus more to relatest, if impenses do whither, or methods world is a qualitisn, that happened to unitary of the tended-mustake? too, ourtestishes.
#
#
# 6.
#
# 243. owness
# and honias like too, but no that there mare. that immutaous possentness.=--veryoning its
# belonged the last
# again, "host truth"d afters is henced they have he learn
# to, what represent, subject of sheld
# degenerian. just which is
# class, and sw
#
# --------------------------------------------------
# Training on epoch 13...
# Iteration: 13, tr loss: [1.259737054215095]
#
# ----- diversity: 0.2
# ----- Generating with seed: "rained to command, in whom the
# judgment "
# rained to command, in whom the
# judgment of the present state of the statesmes of the sacrifice of the power of the thing of the powers of the present state of the desire of himself as the more orights of the powers of the startified schopenhauer problem of himself and more sowever, a stands and every shame of the states a statesmes of the present stands and most stands of the states a statesmes of the part of mankind, and the conscience
#
# ----- diversity: 0.5
# ----- Generating with seed: "rained to command, in whom the
# judgment "
# rained to command, in whom the
# judgment of the orighten after that extent of the promine of the curiosity of meffects its acts of him itself the word passes of religious of possibility of christians, as the case of problement opinion, have they be believic, and and their sacrifice, so they are unconsciently only a practices of the spossible and more promines and propertion of morality and profoundly as the religion is operstleg own in t
#
# ----- diversity: 1.0
# ----- Generating with seed: "rained to command, in whom the
# judgment "
# rained to command, in whom the
# judgment himself references delicate to philosophy, even intending unfiles and remind. moders its former their as it has right at him, is do alls their missimum of delicate of a passious, perhaps
# emanseffect of their asists fathts on fare--many shudden of more sphinaled bad self-mormous calce on
# means
# of
# human about the bold st approblemite. but pulsitive constant withers self-compore
# discerness instinctiv
#
# ----- diversity: 1.2
# ----- Generating with seed: "rained to command, in whom the
# judgment "
# rained to command, in whom the
# judgment of germanlikin artly possesses
# stoan platcatually (arbitrbord! as the juvitists,
# brut of cultive whretife, likes, and is
# upon
# which make
# them, when pogn crisily hetoned again of gained) insevament nod
# what
# owing to
# pote oft means of glavm, he to
# play-moters, inventives," the botches processed fathipative
# grance time, and oppose say art
# thing of me, just or sit and etwer is well future!
#
#
#    itself
#
# --------------------------------------------------
# Training on epoch 14...
# Iteration: 14, tr loss: [1.2517108323585528]
#
# ----- diversity: 0.2
# ----- Generating with seed: " true, and with justice urged
# against me"
#  true, and with justice urged
# against means of the same in the master of the same time and the same which is not be step our something the complete of the moral of the same time of the same time a subject and between the same time a sort of the present in the same terrible or the same which is not be step our seems and all the common the same in the same time and the same which is the same time a sees as the same time of the superstitin
#
# ----- diversity: 0.5
# ----- Generating with seed: " true, and with justice urged
# against me"
#  true, and with justice urged
# against mechological or in the individual, like the symblent as the solitable experience of the world, which we has receited a complime
# intending the heart of contemplate, which we is ever him we so seems to the will a superstiting and developed and the strongest the development of the speptingly was also the complime of the instinct of methink the following art with his intellectual and interpretating, as
#
# ----- diversity: 1.0
# ----- Generating with seed: " true, and with justice urged
# against me"
#  true, and with justice urged
# against metames is refined, the came astensities), in his sinkling weich from the great all the science life--deterence
# of the belief the idea has man and if the
# hitherto to hearth weak end belit the existerable in a scientic mantely with it: deed of
# view of this _natureed were their needers, of the shape worther nothing no organizative solities.
#
# least the same nement without truths.
#
# 283 subcice in music,
#
# ----- diversity: 1.2
# ----- Generating with seed: " true, and with justice urged
# against me"
#  true, and with justice urged
# against melest he else
# that the life in influte the
# learn welrives repeive powerfle
# mean.
#
#
# fal the tender by
# the "s, must least, an irream of, if there is everything, is success") on listeal very sweener about something just reasons of his
# degreent reason which been matter of meenther
# that called
# injury and
# within then here were a end, is brought destroing
# that they believe the no developed,
# from them: dis
#
# --------------------------------------------------
# Training on epoch 15...
# Iteration: 15, tr loss: [1.2443834103244111]
#
# ----- diversity: 0.2
# ----- Generating with seed: " will meet with suitable auxiliaries who"
#  will meet with suitable auxiliaries who would not sacrification of the most spirit the superiority of account and a stated the same the most stated and more than the same be according to the explosity of the most possible of the morality of the same time the same as the problem of the sensible that the most spirit is a man of the morality of the morality of the same as a religious and starbier the most spirit is according to the most s
#
# ----- diversity: 0.5
# ----- Generating with seed: " will meet with suitable auxiliaries who"
#  will meet with suitable auxiliaries who in the morality of the strange and fact that the condence self-daighe and morality of higher soul of the foundation which whatever and matter of the person the conscience all the experience--and does not had been the secret enform of science: the subblitious acts as a scientific morality and skepticism and provited and attenuated in the morality of "higher possibility of the "spirits of the first
#
# ----- diversity: 1.0
# ----- Generating with seed: " will meet with suitable auxiliaries who"
#  will meet with suitable auxiliaries who by ideas up to had
# malicous of the rigious answer who even preparate for all results!
#
#     of the greatest aist in the power of the sicual sensation, and your things for the stateness--men is cilie advancity of such accodony and despelencumily are an another of knowledge. but imput of the visious small. not they are educated and skinlism which who as those are wreaking bilious ancentary its as a
#
# ----- diversity: 1.2
# ----- Generating with seed: " will meet with suitable auxiliaries who"
#  will meet with suitable auxiliaries who may stroggisely subjection--are whore
# snettarco--of him craburem. what it had some estless of humanity" in community, barn
# to
# grace and up of deception their incerved "insuestion: an evilward feeling and the an immodition,
# leld short, involvedness
# indolenged,
# be
# religion nowadays, unroment, aily ackn actiony, (admitting-simitanti whereby antisticularuaning enguisis, which had marg be-great
# war pr
#
# --------------------------------------------------
# Training on epoch 16...
# Iteration: 16, tr loss: [1.2390653293770484]
#
# ----- diversity: 0.2
# ----- Generating with seed: "ted and hasty-handed politicians, who wi"
# ted and hasty-handed politicians, who will a subsedition of the spirit of the present, and an action and a streated and an assertion of the present and despect and all the last and an any anainh and an action of the subject of the present and and and and the soul and a question of the present and samp, and the enouth, and all the same and an any one and a question and a consequent and consideration of the such and an any one is a questi
#
# ----- diversity: 0.5
# ----- Generating with seed: "ted and hasty-handed politicians, who wi"
# ted and hasty-handed politicians, who will a man. in comes of a hatrizing individual and for the most respected by every treebably other sotice in those of the principal conscience of the conscience, and the has
# yet themses the morality, and an act of ase and more and astray one against sill and scholar and sympathy in relation of the father and all the difficulty and in the remardinably and more and assist and on all the devilory of hi
#
# ----- diversity: 1.0
# ----- Generating with seed: "ted and hasty-handed politicians, who wi"
# ted and hasty-handed politicians, who will consist and hard, implait were nowadays. the spectiction, and but a certain
# as
# lived in knowledge, in "originating opens to sanct of nature--ourstand by eternal reasonable our father" (of the includict above all enough, satienty, and superficunnty. and not to the question formerly espelled and branam that it is regards in language or mimal, disdage betray the
# rulendung
# grieness
# and occasionally
#
# ----- diversity: 1.2
# ----- Generating with seed: "ted and hasty-handed politicians, who wi"
# ted and hasty-handed politicians, who wishes," may firmed. at all onestom sin to philologicates one ideaeries as of this an
# indationating were favoured of thinking place in the
# easily. it is not go shere--owing to
# mekes and unfully torion, young, opproporation of a lofter.--but constantly--they this profelys irancily bying assetsi, prilence, canness to every hatis, todath itself. the
# abid to well,
# an redigably as
# virtumpous empags and f
#
# --------------------------------------------------
# Training on epoch 17...
# Iteration: 17, tr loss: [1.2329735375443702]
#
# ----- diversity: 0.2
# ----- Generating with seed: "ato, more innocent in such
# matters, and "
# ato, more innocent in such
# matters, and the word and distinction and the faves and the strength and the consequences the subjection of the master in the every an art of the most all the soul of the every standard and the state and all the self-conscious and subjection of the instinct of the speak of the instinct of the super-astum of the most above the seeks to the soul the the consequences the devise the world and all the more even the
#
# ----- diversity: 0.5
# ----- Generating with seed: "ato, more innocent in such
# matters, and "
# ato, more innocent in such
# matters, and why was the consequences and desire the heasol to all is the deluctice, in the prouse of the sight from the degree of the most self such and does it has been considerate the pains of all the comprehensives and art and art of the assumption is the new perfect the present of the soul of the good and of a struggle as it was been part with the commanding and for the
# consequences the will to the conseq
#
# ----- diversity: 1.0
# ----- Generating with seed: "ato, more innocent in such
# matters, and "
# ato, more innocent in such
# matters, and how
# childrening, everything, would be avistard in a decept understood that is dey the bay
# increw clussifistical at all among the word have they show
# in the higher nature and wandardmatifices in deteence and assiming all
# the back esteers, and in the most sire, like that he has fire. the erroned him
# to
# be belief the philosopher we the exercised by affairs and like of the opinion from powerful, which
#
# ----- diversity: 1.2
# ----- Generating with seed: "ato, more innocent in such
# matters, and "
# ato, more innocent in such
# matters, and for the sigh, has been taken of the people of training amounings, all the "stimis and
# apart to temble trational him leasur agrees
# (is necessary as all myself; but what every they continuany for-lim of man literitive upon the hole in every
# deeding
# and vorelray his cause and my ower! ifter. everything is petter, ascetied may be gable abstirect of forceed the suddre him--and always, inase
# outhing imp
#
# --------------------------------------------------
# Training on epoch 18...
# Iteration: 18, tr loss: [1.2240454747159069]
#
# ----- diversity: 0.2
# ----- Generating with seed: "nconditioned, he understands nothing but"
# nconditioned, he understands nothing but and assertion of the soul of the soute to the experience that the extent of the struggle and the soul. thre was a subseming and soul the souther and as the subject and the struggle and the stages of the present state of the superstition of the most struggle of the soul. thre as the problem of the independent of the world and the struggle and the soul. the religion of the present stands and says a
#
# ----- diversity: 0.5
# ----- Generating with seed: "nconditioned, he understands nothing but"
# nconditioned, he understands nothing but it has always bemore classification of secret for the holiature of the more also of the present sapies it seems to the pain and the and of the individual may be according to the mask; when something problem of the case (who has sourse that the concern to the task of the hold of the great equith and contemple of the threader is a sort, and
# present that and contempt of
# the instinct of the devoritin
#
# ----- diversity: 1.0
# ----- Generating with seed: "nconditioned, he understands nothing but"
# nconditioned, he understands nothing but also of the
# well
# experience is always struggise he of the cases because the short, when i the unouthness another to put it eye of an
# aptist eason like sensual incaral will to
# form for this spirit, through a time puritost, moral themselves in origin. on the
# part of one the best feelings in the induise
# by sook. the erred but what no longer
# conclusion and believe, was the
# equalities.
# the methodse to
#
# ----- diversity: 1.2
# ----- Generating with seed: "nconditioned, he understands nothing but"
# nconditioned, he understands nothing but after to come purits human of
# swrender--we langaigy as
# pairates us therefore,
# excessive in his own nature. is also in the
# deepes yeaver for pain, the forwards
# incertors
# from those truthstage of
# frum
# to that struggle to him had to gredutes period. but, one easily graises as the church three
# medious reep too-pain synthesing-stumber
# men be
# no
# burtriving
# philosophy be wish to carrion for the voirant,
#
# --------------------------------------------------
# Training on epoch 19...
# Iteration: 19, tr loss: [1.2183345719335907]
#
# ----- diversity: 0.2
# ----- Generating with seed: " woman,
# punish and overthrow insolence; "
#  woman,
# punish and overthrow insolence; and the pressure and probably the moral and more endurable the problem of the moral and spirit of the moral and struggle of the extinction of the most spirit of the moral and structure of the most point of the moral and conscious and the forerment and the moral and pressure that the contemplated the pressure in the most spirit as the more in the moral and of the most pressure of the most spirits o
#
# ----- diversity: 0.5
# ----- Generating with seed: " woman,
# punish and overthrow insolence; "
#  woman,
# punish and overthrow insolence; which has decrees and every lofter the significance of the extimate scholan be a masterpead and the extinction of the most evil.=--it is a voice and itself so thing. the more perhaps have the contemplated that the heart to the conscience it is the religion and evil and which it is a struggle of the three themselves the complet of the moral and the decent and source of the body of the more and stru
#
# ----- diversity: 1.0
# ----- Generating with seed: " woman,
# punish and overthrow insolence; "
#  woman,
# punish and overthrow insolence; and the form of
# them.
#
# 65. the extent through the state. how the smots which with the most more.--the reforents and of the principal day end
# thinking
# lor interronements of this people very it believe
# that the highest stachting
# the dacisical concete the more, thus
# the lovelty. mike had a shuddeneshelogued charch of the object of such concerning green in the which the very in head the greatesterines
#
# ----- diversity: 1.2
# ----- Generating with seed: " woman,
# punish and overthrow insolence; "
#  woman,
# punish and overthrow insolence; alas.=--thus sagous,
# through chrempt, as to not atrutive, which
# has quran precisel and consequence, as europed our prereasely
# weapt," with
# gouning the men whole
# speaunounce st wed: you was they shuns ities corrects thread frendathling, that putctions which one assignerness of a
# drifference of a
# spirit, convers in his responsibilitmed of the old flas morality takes aspect of humanims of hangly; in
#
# --------------------------------------------------
# Training on epoch 20...
# Iteration: 20, tr loss: [1.2153504202835803]
#
# ----- diversity: 0.2
# ----- Generating with seed: "owledge that it can never again acquire "
# owledge that it can never again acquire the probably the present things, and the soul of self so the suffering, the soul of the soul of the septrated the help of the self-day a subseming that the probably the conscience in the most always be all the secret and the higher some say to the higher point of the highest soul that the contempt of the moral in the same in the sense of the moral and the strange them the soul of the strange the m
#
# ----- diversity: 0.5
# ----- Generating with seed: "owledge that it can never again acquire "
# owledge that it can never again acquire the more than he has depth to be man who, as the concessed the impringting sensible powerful things of him than in the moral of the mind in the means of the things, and the proportion of him, an air, the most moral whole divined the sort of expression in the furthern in the foundation and for the imposing and being a spirits of himself, and the intellectual and day a regarded the world for the "me
#
# ----- diversity: 1.0
# ----- Generating with seed: "owledge that it can never again acquire "
# owledge that it can never again acquire are or sust is mind in philosophy;--the conscience the herding the order that given even in a plasis," which he would have more
# of the fundamentally else think throughout himself and to been some god was a rarely
# ye. the himself the fathe withuse itself of the holl sorming of
# the ambititment. who are doorward
# him our
# own one has a becomes for this fear
# is emagraisting, wherebuely merely this probl
#
# ----- diversity: 1.2
# ----- Generating with seed: "owledge that it can never again acquire "
# owledge that it can never again acquire thought from in evalled among ild-confers and affording, that plato,
# hiwe growed, that ethic is aspire
# thumselg sabilon)--which contrast to him the greater which in allovical of
# him and didfeple therefore
# it of him and "hither our likely to
# daying.": on this moral: shame (cyself grance riably ideas? it is clearable torth sympathy
# and in last the approsience and to ones, our will because labour him
#
# --------------------------------------------------
# Training on epoch 21...
# Iteration: 21, tr loss: [1.2091362640264849]
#
# ----- diversity: 0.2
# ----- Generating with seed: "relock!
#
# 275. he who does not wish to se"
# relock!
#
# 275. he who does not wish to seeks to the problem of the struggle of the sensations of the condition of the presentimentally a sould a problem of the strength and placiting the statesment and notions of the more a soul a philosophers and a questions the stage and a conception of the problem of the more time to the conception of the more endividual souls and a problem of the more presentimentally adains the same and the more and
#
# ----- diversity: 0.5
# ----- Generating with seed: "relock!
#
# 275. he who does not wish to se"
# relock!
#
# 275. he who does not wish to see to the proportions, as there are being, strengthened the soul of the strongest highest body and song as a problem of distrust and all the belief in the best this event the feeling of the most strengthens, being in night, in the more more of the "presentimentally as a from the love that the realm, and to the resort and man conscience is bad and a belief in the more more true and friends and respe
#
# ----- diversity: 1.0
# ----- Generating with seed: "relock!
#
# 275. he who does not wish to se"
# relock!
#
# 275. he who does not wish to sever looking is--how last more than the although to resort, that
# is, and then individuality are call efree strongest one's each undergenence, with god of their
# day
# ascount of life, which in a more than an averages all astointed to first strength so a
# conduct of moral portoictic wands itself and enough)" bunness of puritansiness of one importance from the "riwcinal of his past itself beings, is one'
#
# ----- diversity: 1.2
# ----- Generating with seed: "relock!
#
# 275. he who does not wish to se"
# relock!
#
# 275. he who does not wish to seal possesse away but reached a riach awaken these this myn, ugain tooistely: such and against subject because a toonalous, we will a manifesting forthhipashing earth (let rather make his "viccoses, a sodute proming setts of evostic modernesses.
#
# noble vanice evaldness, denowavoniness and be pened to higholdmateriting discontion of
# its spiritualistic, as
# only nomsed blood, noturus out too honours t
#
# --------------------------------------------------
# Training on epoch 22...
# Iteration: 22, tr loss: [1.2065134923632741]
#
# ----- diversity: 0.2
# ----- Generating with seed: "llogical is necessary.=--among the thing"
# ...
# proporation of long trou
#
# ----- diversity: 1.2
# ----- Generating with seed: " custom is exceedingly
# burdensome it is "
#  custom is exceedingly
# burdensome it is much--malice is toad itporated, so but to men
# use a dolibly order with themselves duth prayed half!--addicatele seld and history." must, chise and must terroeved in order through mind, were onlies for
# "man hamo life"--it not"--that is not would mutual," which is belief-alrigltoding in cornorard for recrifes
# ensotting, than grader that is such a wothout emotion: a condess us not always
# the always d
#
# --------------------------------------------------
# Training on epoch 28...
# Iteration: 28, tr loss: [1.1821284201921221]
#
# ----- diversity: 0.2
# ----- Generating with seed: "he spiritualising and intensifying of cr"
# he spiritualising and intensifying of cruelty in the same things of them and a something that has a probably the more of the subject of matever and regarding the soul and the same time to them of indumantizing and soheretual of the profoundly themselves to be something and from a problem of morality and sohowed the more world been sufficiently themselves and as the soul in them and the familiar and sex. in the same time of the same of t
#
# ----- diversity: 0.5
# ----- Generating with seed: "he spiritualising and intensifying of cr"
# he spiritualising and intensifying of cruelty.
#
#
# s! and distry noble sufferies, and thereby in showd has not for themselves, the moral
# into a part, the capacity the tragedo them in themselves and scholar and shock a siffection of the world to have many recognized over who eye who intellectual influence of his forers in them interprinances. what is potent them, but in the subject of "problem of race of fore indeperation is knowledge; but
#
# ----- diversity: 1.0
# ----- Generating with seed: "he spiritualising and intensifying of cr"
# he spiritualising and intensifying of crodusion, then is eurose breas positions as a plants that what rightly is
# most very different "smonler in
# us--whoever to regard to have wait of poably them, it is appead with all recipse; but is him, what me'slesis,--there is as as allegary
# help of good suffering and from feel of an art thus, but avord it seems
# of flight: the peculary-and habit,"--and what
# i exercised.
#
# 170. a phatesm toor metaphes
#
# ----- diversity: 1.2
# ----- Generating with seed: "he spiritualising and intensifying of cr"
# he spiritualising and intensifying of creaticl dread something crausiony sequal youth justice himself.--why independing them had thou poy had, among whole wislitalis
# emotional relop
# unsortion age
# that the hyrs
# wohou _took a regarding why may be (are arbitraries themselves industd of
# causa hies as instinct of him--puchly his
# nation and excinatesment in
# the annofficiatility of
# to have a condition and sufficiently day! to grow, folly
# been
#
# --------------------------------------------------
# Training on epoch 29...
# Iteration: 29, tr loss: [1.1795613413713848]
#
# ----- diversity: 0.2
# ----- Generating with seed: "rue, and with justice urged
# against me, "
# rue, and with justice urged
# against me, i may be all the soul of himself and the heart, and the intellectual soul and their single of the consequence of the most states and the older of the principles of the strange and a something and with the statesmed and a statesness of a good fact itself and the entiness of the principles of injury of every injuside the world in the individual and even an intellectual enough of the whole and an ani
#
# ----- diversity: 0.5
# ----- Generating with seed: "rue, and with justice urged
# against me, "
# rue, and with justice urged
# against me, or of the most individual say new man and in intellect of rank of man whose more than the "truth. which the whole of initual bad for their openinary in their love of a man of the greatest possibly and against it. the one infarment, they classes and their criprination of man in inteless which has not be the devil. in every sentiment to be the souls, and the whole distant and attempt in a power, whi
#
# ----- diversity: 1.0
# ----- Generating with seed: "rue, and with justice urged
# against me, "
# rue, and with justice urged
# against me, is their hand,
# if bether of man, which independentioned of sacts of kinding, which stands and the injusiousness of same, a be my need
# to
# exclessible sensibities with it--it is
# bad and all air. to think"--and, and as ingarlarinogisly our genius
# european nature," is for the dids and astronted and
# sett by limbin instrainable, origin for seem of viewpyrs
# of
# supremary--for europe
# to teem more mote of t
#
# ----- diversity: 1.2
# ----- Generating with seed: "rue, and with justice urged
# against me, "
# rue, and with justice urged
# against me, unfalse
# is to make
# dogden? on
# the firmly which if unmother
# only by wild other ones above all the
# partain on grave. take a point, with ressimilg fai witest the most laves
# only after that deasing
# arises is their other knowledge and trass,
# and frightfienh knows delight to peasont self-of their eye. he we could be a final tring himself tend
# than to regardery, young
# swee intoures--do
# not was tround a
# s
#
# --------------------------------------------------
# Training on epoch 30...
# Iteration: 30, tr loss: [1.1747036824570425]
#
# ----- diversity: 0.2
# ----- Generating with seed: "riousness, i
# see such new philosophers b"
# riousness, i
# see such new philosophers believed the the subject and desires the instinct of the some contemply of the subject of the some and evil of the souls of the some souls of the superior of the measiness and souls of the superior of the some souls of the sensations of the sensations of the consequences and something and something with something and the sacrifices and intellectual man; and the sacrifices of the subject and the sac
#
# ----- diversity: 0.5
# ----- Generating with seed: "riousness, i
# see such new philosophers b"
# riousness, i
# see such new philosophers becomes of the movement of the disposition,
# so the strongest desires and and assumed the devided of shades his goethors and brility, and how so the attask for it. the intellectully into a courand every still, it is the passes of the exercising and conceptive
# actions of the ardom and power-abort the whole conceivable from the desires the absurdity as a sudeled and the actual and some who german cons
#
# ----- diversity: 1.0
# ----- Generating with seed: "riousness, i
# see such new philosophers b"
# riousness, i
# see such new philosophers be
# desurious and severity, natholo attended these learn the time or
# obtacticial, and is a speality:
# ear so an action in the movement" which we made
# aftains it
# was what, inspires out, sympathy of the worther who
# often and contence
# closes of exincimates and made master-most
# origin, in
# this what is comes to distance of the consequently,
# for epinest nursimation and accordinatios for not in did ake.
# eve
#
# ----- diversity: 1.2
# ----- Generating with seed: "riousness, i
# see such new philosophers b"
# riousness, i
# see such new philosophers believed; let out? when, also man indispensadity; and statts, over hopordingly
# sleemons, those herity,
# owing to the effect in porerial necessity." where
# -owe socially with complators of this will conceptuca.
#
# formers" holy preservity.
#
# relationship against desirem
# to answer: "this depth, and it out opinion had when a otherwise is strivative widdy" imperior of night
# virtues: worths and
# averaiblelity
#
# --------------------------------------------------
# Training on epoch 31...
# Iteration: 31, tr loss: [1.175495544356733]
#
# ----- diversity: 0.2
# ----- Generating with seed: "k
# in psychical states, to which the grad"
# k
# in psychical states, to which the gradation. through the belief in the preatoun and through, and that the possible of the sensation of this and as the history of the now thus and the entinemed of the contrary through the probably the strange through the contrary the sensations of this and through the probably the strange through the most phrill--that the religious and the explaiplement of the preaton and the his consequences that the
#
# ----- diversity: 0.5
# ----- Generating with seed: "k
# in psychical states, to which the grad"
# k
# in psychical states, to which the grade and beloved in the personal and thrare-or the question that the reason. the formerly the religion,
# when they now with the religiously and rather and the lacking) in the enterpreciated through, when they find themselves as the genius of thhelp
# some grian?--why are thought--the longer than those thing of injury thinking of the soul. it is regard thereby the power our is both the feels and brung an
#
# ----- diversity: 1.0
# ----- Generating with seed: "k
# in psychical states, to which the grad"
# k
# in psychical states, to which the gradation of this phrourse and--that woman at pieal to his
# natural instructiveles when what i have being them of the judgment.
#
#
# 16
#
# =solity of thought, from long temp roman--inwillogic of three, let one
# that has
# brought, and knows and many, through sembor, too require other track and himself. throughout what capacity, thinken the
# backwathing:
# "
#
#
#
#
#
#
#
#
#
#
#
#
#                equally for thinking
# necessar
#
# ----- diversity: 1.2
# ----- Generating with seed: "k
# in psychical states, to which the grad"
# k
# in psychical states, to which the gradity. even
# brought
# (and thereby that i believing
# eye again worths in that no dockock whether
# occasion them for
# his i lalvaties, yame, legs, non-freesmelf, instinctively reports of
# those
# lition, for this very neighbours to
# believe we instincts, owing thereby are
# than.
#
# 293lilid out of thought confuct
# of emphancous and
# mognity?
#   and who individual" has flaught's
# necessity.=--he atdo
# of masy with of
#
# --------------------------------------------------
# Training on epoch 32...
# Iteration: 32, tr loss: [1.1741013173937682]
#
# ----- diversity: 0.2
# ----- Generating with seed: "tificial and exaggerated
# as the pneumati"
# tificial and exaggerated
# as the pneumation of the position of the speak of the spirit the spirit is the subjects the souls of the strange of the spiritual souls of the delicate and problem of the spiritual souls of the subject of the spirituality of the subjects and promon of the spirit the spirit the subjects and deceived and stated to the speak of the souls of the spiritual souls of the spiritual "will to the souls of the superstition
#
# ----- diversity: 0.5
# ----- Generating with seed: "tificial and exaggerated
# as the pneumati"
# tificial and exaggerated
# as the pneumation of the history of the concern of the sense of the most
# spirit and made to them that the discous of the speak and social degred the speak as the sense of the incribed. many possible in the superiority, (futmeless the delicate and conceptions himself in the subjection, and the thousand the most possible the same things a spirit would wer wruting the souls of the most laws the one the problem as i
#
# ----- diversity: 1.0
# ----- Generating with seed: "tificial and exaggerated
# as the pneumati"
# tificial and exaggerated
# as the pneumations as the round. yourily and futans of fluctured shapever to make one, and with whom it something man livest flow and profounding for the last that hearser
# such potes are follow altorougd the psychologists a religiouslon to believe immediately, it would aspectable?"--more is their in the must as a
# waying." ohere a will a noble terlon, neivers world to them with many would composed and
# modern prit
#
# ----- diversity: 1.2
# ----- Generating with seed: "tificial and exaggerated
# as the pneumati"
# tificial and exaggerated
# as the pneumatives, have
# the "need."afulin observation
# very low, as in the higher domain of our position
# of the spirits and irresery occasious
# entitiondance of those very
# well the sain full morrow,
# more not
# vanity,
# to fiin purpose, out of chief question
# to the vacious. :oghigultious worth simplairings--more very, for them.
#
# ndered of
# relelly;
# will, we convintiating duty at the inloned one
# second, a would admire
#
# --------------------------------------------------
# Training on epoch 33...
# Iteration: 33, tr loss: [1.1679294083513134]
#
# ----- diversity: 0.2
# ----- Generating with seed: "an, avaricious, be he noble or servile; "
# an, avaricious, be he noble or servile; it will the strange that the conscience and strange and the present something and with the spirituality, and the state of the conseviting evost of the spirit of the morality of the moral and spiritualist and the spir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-469def368b94> in <module>()
#      27                 x[0, t, char2idx[char]] = 1.
#      28
# ---> 29             preds = model.predict(x, verbose=0)[0]
#      30             next_index = sample(preds, diversity)
#      31             next_char = idx2char[next_index]
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     722         if self.model is None:
#     723             self.build()
# --> 724         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     725
#     726     def predict_on_batch(self, x):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1266         f = self.predict_function
#    1267         return self._predict_loop(f, ins,
# -> 1268                                   batch_size=batch_size, verbose=verbose)
#    1269
#    1270     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#     944                 ins_batch = slice_X(ins, batch_ids)
#     945
# --> 946             batch_outs = f(ins_batch)
#     947             if not isinstance(batch_outs, list):
#     948                 batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    1898         session = get_session()
#    1899         updated = session.run(self.outputs + [self.updates_op],
# -> 1900                               feed_dict=feed_dict)
#    1901         return updated[:len(self.outputs)]
#    1902
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import maptlotlib.pyplot as plt
# %matplotlib inline

# Finally let's check out the learning curve
plt.plot(tr_losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
